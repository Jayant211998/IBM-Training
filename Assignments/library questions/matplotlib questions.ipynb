# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
#Question1

# %%
x=[1,2,3,4,5,6]
y=[10,20,30,40,50,60]
plt.plot(x,y)
plt.xlabel('X-AXIS')
plt.ylabel('Y-AXIS')
plt.title("Title")
plt.show()

# %%
#Question2

# %%
x=list(map(int,input().split(" ")))
y=list(map(int,input().split(" ")))
plt.plot(x,y)
plt.xlabel('X-AXIS')
plt.ylabel('Y-AXIS')
plt.title("Title")
plt.show()
# Out:
# 1 5 3 2
# 1 5 2 3

# %%
#Question 3

# %%
f=open('text.txt').read()
f=f.split('\n')
c=[int(i.split(' ')[0]) for i in f]
d=[int(i.split(' ')[1]) for i in f]
print(c,d)
plt.plot(c,d)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('title')
# Out:
# [1, 6, 2, 8, 10] [4, 3, 7, 9, 15]
# Text(0.5, 1.0, 'title')

# %%
#Question4

# %%
language=['Java','Python','PHP','JS','C#','C++']
popularity=[22.2,17.6,8.8,8,7.7,6.7]
plt.bar(language,popularity,color='red')
plt.xlabel("Languages")
plt.ylabel("Popularity")
plt.title("Title")
plt.show()

# %%
#Question5

# %%
language=['Java','Python','PHP','JS','C#','C++']
popularity=[22.2,17.6,8.8,8,7.7,6.7]
plt.barh(language,popularity,color='red')
plt.xlabel("Languages")
plt.ylabel("Popularity")
plt.title("Title")
plt.show()

# %%
#Question6

# %%
men = (22,30,35,35,46)
women = (25,32,30,35,29)
fig, ax = plt.subplots()       #------
index = np.arange(5)    #------
width = 0.4
rects1 = plt.bar(index, men, width,color='b',label='Men')
rects2 = plt.bar(index + width, women, bar_width,color='g',label='Women')
plt.title('Title')
plt.xticks(index + width, ('A', 'B', 'C', 'D','E'))
plt.show()

# %%
#Question7

# %%
x=pd.read_csv('sample.csv')
df=pd.DataFrame(x)
print(df.plot.bar())
print(x)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
#    a  b  c  d  e
# 0  4  8  5  7  6
# 1  2  3  4  2  6
# 2  4  7  4  7  8
# 3  2  6  4  8  6
# 4  2  4  3  3  2

# %%
#Question 8

# %%
x=pd.read_csv('financial.csv')
df=pd.DataFrame(x)
print(df.plot())
print(x)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
#          date        open        high        low        close
# 0  10-03-2016  774.250000  776.065002  769.500000  772.559998
# 1  10-04-2016  776.030029  778.710022  772.890015  776.429993
# 2  10-05-2016  779.309998  782.070007  775.650024  776.469971
# 3  10-06-2016  779.000000  780.479980  775.539978  776.859985
# 4  10-07-2016  779.659973  779.659973  770.750000  775.080017

# %%
#Question9

# %%
x=pd.read_csv('sales.csv')
df=pd.DataFrame(x)
print(x)
plt.plot(x['month_number'], x['total_profit'])
plt.xlabel('month')
plt.ylabel('Profit')
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %%
#Question10

# %%
x=pd.read_csv('sales.csv')
df=pd.DataFrame(x)
plt.plot(x['month_number'], x['total_profit'],'--',color='red',linewidth=3,marker='o')
plt.xlabel('month number')
plt.ylabel('sold unit number')
# Out:
# Text(0, 0.5, 'sold unit number')

# %%
#Question 11

# %%
x=pd.read_csv('sales.csv')
y=[x['facecream'],x['facewash'],x['toothpaste'],x['bathingsoap'],x['shampoo'],x['moisturizer']]
df=pd.DataFrame(y)
print(df.plot())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
#Question 12

# %%
x=pd.read_csv('sales.csv')
df=pd.DataFrame(x)
plt.scatter(x['month_number'],x['toothpaste'],)
plt.grid( linestyle='-.')

# %%
#Question13

# %%
x=pd.read_csv('sales.csv')
df=pd.DataFrame(x)
tp = x['toothpaste']
fw = x['facewash']
fig, ax = plt.subplots()       #------
index = np.arange(5)    #------
width = 0.4
rects1 = plt.bar(index, men, width,color='b',label='toothpaste')
rects2 = plt.bar(index + width, women, bar_width,color='g',label='facewash')
plt.title('Title')
plt.xticks(index + width, (x['month_number']))
plt.show()

# %%
#Question14

# %%
x=pd.read_csv('sales.csv')
df=pd.DataFrame(x)
months=x['month_number']
bs=x['bathingsoap']
plt.bar(months,bs,color='green')
plt.title("Title")
plt.show()

# %%
#Question15

# %%
x=pd.read_csv('sales.csv')
df=pd.DataFrame(x)
month=12
profit=x['total_profit']
plt.hist(profit,month)
plt.show()

# %%
#Question 16

# %%
x=pd.read_csv('sales.csv')
df=pd.DataFrame(x)
l=[sum(x['facecream']),sum(x['facewash']),sum(x['toothpaste']),sum(x['bathingsoap']),sum(x['shampoo']),sum(x['moisturizer'])]
m=['facecream','facewash','toothpaste','bathingsoap','shampoo','moisturizer']
plt.pie(l,labels=m)
plt.show()
