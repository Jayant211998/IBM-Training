# %% [markdown]
# # Pandas

# %% [markdown]
# # Introduction

# %%
#Pandas is a library written for the python programming language for data manipulation and analysis. In particular,
#it offers data structures and operations for manipulating numerical tables.

# %%
import pandas as pd

# %%
df=pd.read_csv('weather.csv')#reading csv file
df  #printing dataset
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %% [markdown]
# # functions

# %%
df.columns  #gives name of columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
df.dtypes   #gives datatypes of all columns
# Out:
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm       int64
# Humidity9am        int64
# Humidity3pm        int64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am           int64
# Cloud3pm           int64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RISK_MM          float64
# RainTomorrow      object
# dtype: object

# %%
df.index   #gives the starting and endng index of rows
# Out:
# RangeIndex(start=0, stop=366, step=1)

# %%
df.count()  #gives the nmber of non null values
# Out:
# MinTemp          366
# MaxTemp          366
# Rainfall         366
# Evaporation      366
# Sunshine         363
# WindGustDir      363
# WindGustSpeed    364
# WindDir9am       335
# WindDir3pm       365
# WindSpeed9am     359
# WindSpeed3pm     366
# Humidity9am      366
# Humidity3pm      366
# Pressure9am      366
# Pressure3pm      366
# Cloud9am         366
# Cloud3pm         366
# Temp9am          366
# Temp3pm          366
# RainToday        366
# RISK_MM          366
# RainTomorrow     366
# dtype: int64

# %%
df.info()   #gives information about data types and non null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MinTemp        366 non-null    float64
#  1   MaxTemp        366 non-null    float64
#  2   Rainfall       366 non-null    float64
#  3   Evaporation    366 non-null    float64
#  4   Sunshine       363 non-null    float64
#  5   WindGustDir    363 non-null    object
#  6   WindGustSpeed  364 non-null    float64
#  7   WindDir9am     335 non-null    object
#  8   WindDir3pm     365 non-null    object
#  9   WindSpeed9am   359 non-null    float64
#  10  WindSpeed3pm   366 non-null    int64
#  11  Humidity9am    366 non-null    int64
#  12  Humidity3pm    366 non-null    int64
#  13  Pressure9am    366 non-null    float64
#  14  Pressure3pm    366 non-null    float64
#  15  Cloud9am       366 non-null    int64
#  16  Cloud3pm       366 non-null    int64
# ...

# %%
df.describe()  #tells about count,mean and median etc
# Out:
#           MinTemp     MaxTemp    Rainfall  Evaporation    Sunshine  \
# count  366.000000  366.000000  366.000000   366.000000  363.000000
# mean     7.265574   20.550273    1.428415     4.521858    7.909366
# std      6.025800    6.690516    4.225800     2.669383    3.481517
# min     -5.300000    7.600000    0.000000     0.200000    0.000000
# 25%      2.300000   15.025000    0.000000     2.200000    5.950000
# 50%      7.450000   19.650000    0.000000     4.200000    8.600000
# 75%     12.500000   25.500000    0.200000     6.400000   10.500000
# max     20.900000   35.800000   39.800000    13.800000   13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count     364.000000    359.000000    366.000000   366.000000   366.000000
# mean       39.840659      9.651811     17.986339    72.035519    44.519126
# std        13.059807      7.951929      8.856997    13.137058    16.850947
# ...

# %%
df.head()  #gives n number of values from top
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.tail(10) #gives n number of values from bottom
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 356      3.4     15.0       0.8          4.8      11.7           S
# 357      3.2     18.0       0.0          7.4      12.2         SSE
# 358      0.9     20.7       0.0          5.4       8.4         NNW
# 359      3.3     25.5       0.0          5.2      10.8           N
# 360      7.9     26.1       0.0          6.8       3.5         NNW
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 356           70.0          S          S          35.0  ...           24
# 357           48.0        SSE          S          26.0  ...           25
# ...

# %%
df['WindGustDir'].unique()  #for finding unique values in a column
# Out:
# array(['NW', 'ENE', 'SSE', 'SE', 'E', 'S', 'N', 'WNW', 'ESE', 'NE', 'NNE',
#        'NNW', 'SW', 'W', 'WSW', 'SSW', nan], dtype=object)

# %%
len(df['WindGustDir'].unique().tolist()) #for finding number of unique values in a column
# Out:
# 17

# %% [markdown]
# # loc vs iloc

# %%
'''difference between iloc and loc
                iloc uses index of columns to specify them whereas loc uses name of columns
                iloc[0:5,1] gives 5 rows for 0 to 4 whereas loc[0:5,'MaxTemp'] gives 6 rows from 0 to 5
syntax- df.function[<row specification>,<column specification>] 
'''

# %%
#syntax- df.iloc[<row specification>,<column specification>]
df.iloc[0:6,0:4] 
df.iloc[[0,10],[1,7]]
# Out:
#     MaxTemp WindDir9am
# 0      24.3         SW
# 10     25.2         SE

# %%
#syntax simlar to iloc
df.loc[0:5,['MinTemp','MaxTemp']]
# Out:
#    MinTemp  MaxTemp
# 0      8.0     24.3
# 1     14.0     26.9
# 2     13.7     23.4
# 3     13.3     15.5
# 4      7.6     16.1
# 5      6.2     16.9

# %%
df.loc[[0,5],['MinTemp','MaxTemp']]
# Out:
#    MinTemp  MaxTemp
# 0      8.0     24.3
# 5      6.2     16.9

# %% [markdown]
# # SQL operation

# %%
#performing select from where operation on dataset

# %%
df[df['MinTemp']<15]['RainToday']
# Out:
# 0       No
# 1      Yes
# 2      Yes
# 3      Yes
# 4      Yes
#       ...
# 361     No
# 362     No
# 363     No
# 364     No
# 365     No
# Name: RainToday, Length: 321, dtype: object

# %% [markdown]
# # handling missing values

# %%
df.isnull().any(axis=1)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 361    False
# 362    False
# 363    False
# 364    False
# 365    False
# Length: 366, dtype: bool

# %%
df=pd.read_csv('weather.csv')#reading csv file
df[df.isnull().any(axis=1)] #identifing rows containing null values
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 113     12.7     28.6       6.6          3.2       8.6           W
# 118     11.7     27.6       0.0          7.8       8.1           W
# 127     10.8     29.2       0.0          8.4       7.5           E
# 138     12.5     29.9       0.0          5.8      10.7          NW
# 140     11.5     29.3       0.0          5.2       8.0          NW
# 174      7.5     19.0       0.0          4.0       6.8         ENE
# 176      5.0     20.9       0.0          2.0       8.9         WNW
# 180     -2.1     13.8       0.2          1.8       9.5         NNW
# 189     -0.2     18.1       0.0          4.4       9.4          NW
# 193      9.4     19.2       0.0          2.2       7.7         NaN
# 195      2.2     18.6       0.0          2.0       9.2         NNW
# 200     -2.7     18.1       0.0          2.2       9.3           W
# 208      4.9     18.1       5.2          1.2       8.5         NNW
# ...

# %%
#droping values

# %%
df=df.dropna()  #droping rows with null values

# %%
df[df.isnull().any(axis=1)] #identifing rows containing null values
# Out:
# Empty DataFrame
# Columns: [MinTemp, MaxTemp, Rainfall, Evaporation, Sunshine, WindGustDir, WindGustSpeed, WindDir9am, WindDir3pm, WindSpeed9am, WindSpeed3pm, Humidity9am, Humidity3pm, Pressure9am, Pressure3pm, Cloud9am, Cloud3pm, Temp9am, Temp3pm, RainToday, RISK_MM, RainTomorrow]
# Index: []
#
# [0 rows x 22 columns]

# %%
#filling values

# %%
df=pd.read_csv('weather.csv')#reading csv file
df[df.isnull().any(axis=1)] #identifing rows containing null values
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 113     12.7     28.6       6.6          3.2       8.6           W
# 118     11.7     27.6       0.0          7.8       8.1           W
# 127     10.8     29.2       0.0          8.4       7.5           E
# 138     12.5     29.9       0.0          5.8      10.7          NW
# 140     11.5     29.3       0.0          5.2       8.0          NW
# 174      7.5     19.0       0.0          4.0       6.8         ENE
# 176      5.0     20.9       0.0          2.0       8.9         WNW
# 180     -2.1     13.8       0.2          1.8       9.5         NNW
# 189     -0.2     18.1       0.0          4.4       9.4          NW
# 193      9.4     19.2       0.0          2.2       7.7         NaN
# 195      2.2     18.6       0.0          2.0       9.2         NNW
# 200     -2.7     18.1       0.0          2.2       9.3           W
# 208      4.9     18.1       5.2          1.2       8.5         NNW
# ...

# %%
df=df.fillna(0)
df[df.isnull().any(axis=1)] #identifing rows containing null values
# Out:
# Empty DataFrame
# Columns: [MinTemp, MaxTemp, Rainfall, Evaporation, Sunshine, WindGustDir, WindGustSpeed, WindDir9am, WindDir3pm, WindSpeed9am, WindSpeed3pm, Humidity9am, Humidity3pm, Pressure9am, Pressure3pm, Cloud9am, Cloud3pm, Temp9am, Temp3pm, RainToday, RISK_MM, RainTomorrow]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.loc[[113],['WindDir9am']]
# Out:
#     WindDir9am
# 113          0
