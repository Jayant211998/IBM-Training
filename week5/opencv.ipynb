# %%
import cv2
import matplotlib.pyplot as plt

# %%
image=cv2.imread("dhoni.jpg")

# %%
cv2.imshow('captain cool',image)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
print(image.shape)
# Out:
# (900, 1200, 3)

# %%
cv2.imwrite('msd.jpg',image)
# Out:
# True

# %%
image=cv2.imread("msd.jpg")

# %%
img1=cv2.cvtColor(image,cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(img1,cmap="gray",vmin=0,vmax=255)
